# %%
import pandas as pd

# %%
df = pd.read_parquet('data/data.parquet')
df.head()
# Out:
#                  acta_id                   diputado_nombre persona_id  \
# acta_detalle_id
# 1086083             3762  ABDALA DE MATARAZZO Norma Amanda
# 1086084             3762    ACERENZA Samanta María Celeste
# 1086085             3762                       AICEGA Juan
# 1086086             3762          ALLENDE Walberto Enrique
# 1086087             3762              ALONSO Laura Valeria
#
#                                        bloque      distrito_nombre  \
# acta_detalle_id
# 1086083            Frente Cívico por Santiago  Santiago del Estero
# 1086084                                   PRO         Buenos Aires
# 1086085                                   PRO         Buenos Aires
# 1086086             Todos Juntos por San Juan             San Juan
# 1086087          Frente para la Victoria - PJ         Buenos Aires
#
#                        voto  numero origen    anio   expediente  \
# acta_detalle_id
# 1086083             AUSENTE  3337.0      D  2017.0  3337-D-2017
# ...

# %%
df['anio'].unique()
# Out:
# [np.float64(2002.0),
#  np.float64(2007.0),
#  np.float64(2008.0),
#  np.float64(2009.0),
#  np.float64(2010.0),
#  np.float64(2011.0),
#  np.float64(2012.0),
#  np.float64(2013.0),
#  np.float64(2014.0),
#  np.float64(2015.0),
#  np.float64(2016.0),
#  np.float64(2017.0),
#  np.float64(2018.0),
#  np.float64(2019.0)]
